# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://gtu.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___
# <pre>
# <center><b>Python for Data Science - 3150713</b></center>
# <center><b>Lab - 5</b></center>
# <pre>

# %% [markdown]
# # 1)	Scrape the data of Faculty and news data from darshan university website.

# %%
import bs4
import numpy as np
import pandas as pd
import requests

# %%
data = requests.get("https://www.darshan.ac.in/engineering/computer/faculty")
soup = bs4.BeautifulSoup(data.text,'html.parser')
allFaculty =  soup.select('body > main > div:nth-child(5) > div > div > div.col-lg-8.col-xl-9.g-font-size-14 > div > div')

# %%
allFaculty
# Out:
# [<div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Dr-Gopi-Bhupendrabhai-Sanghani';" title="About Dr. Gopi Bhupendrabhai Sanghani, Dean - School of Computer Science, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <img alt="Dr. Gopi Bhupendrabhai Sanghani -" class="img-fluid w-100 g-rounded-top-5 img-faculty" src="https://darshan.ac.in/U01/Faculty-Photo/5---21-06-2021-10-50-15.jpg" title="Dr. Gopi Bhupendrabhai Sanghani is Dean - School of Computer Science at Department of Computer Science and Engineering">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Dr. Gopi Sanghani
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Dean - School of Computer Science
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </img></div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              Ph.D. , M.E. (CE)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          22+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jul-2012
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Dr-Nilesh-Maganbhai-Gambhava';" title="About Dr. Nilesh Maganbhai Gambhava, Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <img alt="Dr. Nilesh Maganbhai Gambhava -" class="img-fluid w-100 g-rounded-top-5 img-faculty" src="https://darshan.ac.in/U01/Faculty-Photo/01CENMG (2)_19042019_063552AM_21052019_044853AM.jpg" title="Dr. Nilesh Maganbhai Gambhava is Professor at Department of Computer Science and Engineering">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Dr. Nilesh Gambhava
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </img></div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              Ph.D. , M.E. (CE)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          19+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jul-2009
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Dr-Pradyumansinh-U-Jadeja';" title="About Dr. Pradyumansinh U. Jadeja, Associate Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <img alt="Dr. Pradyumansinh U. Jadeja -" class="img-fluid w-100 g-rounded-top-5 img-faculty" src="https://darshan.ac.in/U01/Faculty-Photo/02CEPUJ_19042019_063653AM.jpg" title="Dr. Pradyumansinh U. Jadeja is Associate Professor at Department of Computer Science and Engineering"/>
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Dr. Pradyumansinh Jadeja
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Associate Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              Ph.D., M.E. (CE)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          17+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jul-2009
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Maulik-D-Trivedi';" title="About Prof. Maulik D Trivedi, Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <img alt="Prof. Maulik D Trivedi -" class="img-fluid w-100 g-rounded-top-5 img-faculty" src="https://darshan.ac.in/U01/Faculty-Photo/CEMDT01_25042019_022618PM.jpg" title="Prof. Maulik D Trivedi is Assistant Professor at Department of Computer Science and Engineering"/>
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. Maulik Trivedi
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              M.Tech. (CSE)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          14+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jun-2009
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Dixita-Baldevbhai-Kagathara';" title="About Prof. Dixita Baldevbhai Kagathara, Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <img alt="Prof. Dixita Baldevbhai Kagathara -" class="img-fluid w-100 g-rounded-top-5 img-faculty" src="https://darshan.ac.in/U01/Faculty-Photo/9---20-06-2021-10-41-42.jpg" title="Prof. Dixita Baldevbhai Kagathara is Assistant Professor at Department of Computer Science and Engineering"/>
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. Bhushan Joshi
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              BE(EC), ME(EC Embedded Systems)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          5+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jun-2022
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Devangi-Lalitbhai-Kotak';" title="About Prof. Devangi Lalitbhai Kotak, Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. Devangi Kotak
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              M. Tech(CS), BE(IT), Diploma I.T.
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          13+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jul-2022
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Ekta-Dhirajlal-Gevariya';" title="About Ekta Aadarsh Baldha, Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. Ekta Gevariya
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              ME(CE),B.Tech(IT)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          1+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Jul-2022
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Dolly-Bharvada';" title="About Dolly Bharvada, Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. Dolly Doshi
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              ME(EC)
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          3+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Aug-2022
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-10 col-sm-6 col-lg-4 col-xl-3 g-mb-30 g-px-70 g-px-15--sm col-md-6 g-px-50--md g-px-10--lg g-px-15--xl">
#  <div class="g-bg-white d-shadow-v1 d-shadow-v1--hover g-rounded-top-5 g-rounded-bottom-5 h-100 g-cursor-pointer" onclick="location.href = '/faculty-profile/Prof-Kishankumar-Jagdishchandra-Jogi';" title="About KISHANKUMAR JAGDISHCHANDRA JOGI , Assistant Professor, Department of Computer Science and Engineering">
#  <div class="row h-100">
#  <div class="col-12">
#  <div class="g-px-10 g-pt-20">
#  <h2 class="h5 g-font-primary g-color-black g-font-weight-600 text-center g-mb-0">
#                                                  Prof. KISHANKUMAR  JOGI
#                                              </h2>
#  <span class="d-block g-color-primary g-font-weight-600 g-font-size-12 text-center g-mb-10">
#                                                  Assistant Professor
#                                              </span>
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  </div>
#  </div>
#  <div class="col-12">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-500 text-center g-px-20 g-font-size-12">
#                                              B.E.Electrical
#                                          </span>
#  </div>
#  <div class="col-12">
#  <div class="g-px-10 g-pb-20">
#  <hr class="u-divider-linear-gradient u-divider-linear-gradient--gray-light-v2 g-my-5"/>
#  <div class="row text-center g-mb-20 no-gutters">
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Experience
#                                                      </span>
#  <span class="btn btn-sm g-bg-blue-opacity-0_1 g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          7+ Years
#                                                      </span>
#  </div>
#  <div class="col-6">
#  <span class="d-block g-color-gray-dark-v3 g-font-weight-600 g-font-size-10 g-mb-5">
#                                                          Working Since
#                                                      </span>
#  <span class="btn btn-sm g-bg-bluegray-opacity-0_1 g-color-bluegray g-color-blue g-font-weight-700 g-font-size-12" style="cursor: default;">
#                                                          Aug-2022
#                                                      </span>
#  </div>
#  </div>
#  <span class="d-block text-center g-font-size-12 font-italic g-font-weight-400 g-color-gray-dark-v3 g-color-primary--hover">
#                                                  View Profile →
#                                              </span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
for t in allFaculty:
    name = t.select("h2")[0].text.strip()
    designation = t.select("span")[0].text.strip()
    education = t.select("span")[1].text.strip()
    experience = t.select("span")[3].text.strip()
    working_since = t.select("span")[5].text.strip()

    print(name, "-",designation, "-", education, "-", experience, "-", working_since)
# Out:
# Dr. Gopi Sanghani - Dean - School of Computer Science - Ph.D. , M.E. (CE) - 22+ Years - Jul-2012
# 'Bureau of Indian Standards (BIS) Standard Club and Darshan University, Rajkot has organized an industrial visit at “Falcon Pump Pvt. Ltd.” on the date 08th July 2022. The objective of organizing such an event is to create awareness about the importance of BIS standard club activities like standard formation, standard certification & licensing procedures to the students. Initially, Mr. Aman Singh (BIS Promoting Officer) & Mr. Dhanraj Karad Sir (Scientist – B) from BIS has introduced the establishment of BIS standards and after that, they brought the students to visit the industry premises. In the industry premises, they helped students understand the practical application of the BIS standards in the industry.'

# %% [markdown]
# # 2) Scrape the data of student placement from darshan university website.

# %%
data = requests.get("https://www.darshan.ac.in/placement/list/engineering/computer/2023")
soup = bs4.BeautifulSoup(data.text, 'html.parser')
allstudents = soup.select("body > main > div:nth-child(5) > div > div > div.col-lg-8.col-xl-9.g-font-size-14.g-mb-30 > div.g-pt-20 > div.row.g-px-4.g-px-5--sm.g-px-5--md > div")

# %%
#name of students
print(len(soup.select("h2")))#got the lenth of student name
print(soup.select("h2")[1].text.strip())#got the firststudent
print(soup.select("h2")[139].text.strip())#got the last student
# Out:
# 144
# KATHANLUNAGARIYA
# YASHRATHOD

# %%
# got the students' name
Studentname = []
for i in range(1,140):
    a = soup.select("h2")[i].text.strip()
    Studentname.append(a)
Studentname
# Out:
# ['KATHANLUNAGARIYA',
#  'DHAVALBERA',
#  'SOHAMJOSHI',
#  'IKSHIKACHOTAI',
#  'DRASHTIATKOTIYA',
#  'SWAPNILKATHIRIYA',
#  'MIRAL SANGANI',
#  'SURAJKUSHVAHA',
#  'DRASHTIKANSAGARA',
#  'SMITPIPARAVA',
#  'RAJANPANDYA',
#  'VATSALPATEL',
#  'MIHIRKHUNT',
#  'SUNNY MARTHAK',
#  'JAYGOHEL',
#  'ABHAYCHOTHANI',
#  'KHYATIUPADHYAY',
#  'NIYANTAAAMBALIYA',
#  'SHREYGANDHI',
#  'KRUTIBHIMANI',
#  'SHREYAKANANI',
#  'RUSHIKKARAVADIYA',
#  'JENILVASOYA',
#  'VASUDEDAKIYA',
#  'SMIT VAGHASIYA',
#  'MILANBHALODIYA',
#  'RUSHITA SAVALIYA',
#  'KASHYAPGINOYA',
#  'SAVANSORATHIYA',
#  'DIPALIBENBHUVA',
#  'GAURAVVALA',
#  'BHAVYLADANI',
#  'VANSHILPATEL',
#  'JEET PATEL',
#  'SHUBHAMSHAH',
#  'RADHIKARANGANI',
#  'BURHANMAKDA',
#  'OMGAJERA',
#  'JAHNAVIDARANIA',
#  'MAYURDHWAJSINHGOHIL',
#  'BHAVISHAPANJWANI',
#  'HIMANSHULADVA',
#  'YASHSAVALIYA',
#  'DARSHITKUMARGADHIYA',
#  'KHUSHIDADHANIYA',
#  'DIVYANSHURANPARIA',
#  'CHINTANKANSAGARA',
#  'KENILMENDAPARA',
#  'NENCYMAKADIA',
#  'JAYSOLANKI',
#  'NAYANMEVA',
#  'TEJMODI',
#  'HASTIJASANI',
#  'RAJLAKKAD',
#  'VIVEKPATORIYA',
#  'VANDITJOSHI',
#  'AKASHPAMBHAR',
#  'DHARMIKPARMAR',
#  'SEJALGUPTA',
#  'KEVINMUNGRA',
#  'HARSHALKHAMBHADIYA',
#  'HEMALIBEN SANANDIYA',
#  'PRASADMEHTA',
#  'PULINDIDHANESHA',
#  'JAYKUMARMANSURIYA',
#  'ISHANBHATT',
#  'HARDIKCHOKSI',
#  'BURHANBHARMAL',
#  'DARSHIT SHAH',
#  'KEVANGHORECHA',
#  'JANVIBAHENJANI',
#  'NAKSHIKALOLIA',
#  'SHREYAOGANJA',
#  'JAYDEEPMITHANI',
#  'NILONI SONI',
#  'ANURAGPINDORIYA',
#  'DHAVAL GOHEL',
#  'DHRUVKUNDALIYA',
#  'RUTULSORATHIYA',
#  'ISHAVAGHAMSHI',
#  'DHRUVILDOBARIYA',
#  'SHIVAMNANDA',
#  'RINKLEADVANI',
#  'PRIYAMODI',
#  'PARTHDAMANI',
#  'KRUSHNAJOSHI',
#  'DEVANSHIMAKHECHA',
#  'SMITKUMARPADSUMBIYA',
#  'DIVYTHAKRAR',
#  'VATSALBABARIYA',
#  'SMITMESHVANIYA',
#  'URMILPARSANIYA',
#  'VIRAJBUSA',
#  'MONIKABENDETROJA',
#  'ABHAYKAMANI',
#  'VARUNKESARIA',
#  'VIVEKPARMAR',
#  'DEVANGMEHTA',
#  'KARANDAVDA',
#  'DIGVIJAYNAKUM',
#  'JAYDEVCHOTAI',
#  'HARSHILDHOLAKIYA',
#  'DARSHAYBHAYANI',
#  'DEEPKANANI',
#  'PARTHPANDYA',
#  'DARSHANKANGAD',
#  'SAHILVASANI',
#  'SAKSHIBENPATEL',
#  'SHYAMKADECHA',
#  'PRARTHANAKARIYA',
#  'DHAVALDOBARIYA',
#  'HARSHALGAMI',
#  'KALPGORECHA',
#  'TIRTHANAKANSAGARA',
#  'KEVINKANZARIYA',
#  'SAHILKUMARKIKANI',
#  'DHRUV PARMAR',
#  'VIVEKPESHAVARIYA',
#  'JAY PIPALIYA',
#  'BHARGAVKUMARVACHHANI',
#  'KEVALSARDHARA',
#  'CHINTANKUMARSAKHIYA',
#  'RUSHIKKUMARSUTARIYA',
#  'RAHULSAVANI',
#  'RITIKACHAUHAN',
#  'RIDDHIPARMAR',
#  'DHRUVIKANERIYA',
#  'DHAIVATVAGHELA',
#  'YASHJANANI',
#  'DAXITBHUPTANI',
#  'VISHWASADARIYA',
#  'SAGARTANK',
#  'JEELDETROJA',
#  'VIVEKDUBARIYA',
#  'PRINCEFALDU',
#  'RUSHIKDARANIYA',
#  'ISHITVASOYA',
#  'KRUNALPATEL',
#  'YASHRATHOD']

# %%
#checked the students' enrollment number manually 
print(len(soup.select("body > main > div:nth-child(5) > div > div > div.col-lg-8.col-xl-9.g-font-size-14.g-mb-30 > div.g-pt-20 > div.row.g-px-4.g-px-5--sm.g-px-5--md > div:nth-child(139) > article > div > p.g-color-gray-dark-v4.g-font-weight-500.g-font-size-15.g-mb-0.g-font-code")))
# Out:
# 1

# %%
enrollment = []
for i in range(1,140):
    a = soup.select(f'body > main > div:nth-child(5) > div > div > div.col-lg-8.col-xl-9.g-font-size-14.g-mb-30 > div.g-pt-20 > div.row.g-px-4.g-px-5--sm.g-px-5--md > div:nth-child({i}) > article > div > p.g-color-gray-dark-v4.g-font-weight-500.g-font-size-15.g-mb-0.g-font-code')[0].text.strip()
    enrollment.append(a)
enrollment
# Out:
# ['190540107121',
#  '190540107007',
#  '190540107085',
#  '190540107030',
#  '190540107005',
#  '190540107106',
#  '190540107181',
#  '190540107116',
#  '200540107516',
#  '190540107171',
#  '190540107148',
#  '200540107523',
#  '190540107109',
#  '200540107519',
#  '200540107520',
#  '190540107032',
#  '190540107209',
#  '190540107001',
#  '190540107064',
#  '190540107014',
#  '190540107092',
#  '190540107102',
#  '190540107222',
#  '190540107043',
#  '190540107214',
#  '190540107008',
#  '190540107186',
#  '190540107068',
#  '190540107200',
#  '190540107018',
#  '200540107517',
#  '190540107117',
#  '190540107165',
#  '200540107504',
#  '190540107190',
#  '190540107173',
#  '190540107128',
#  '190540107060',
#  '190540107039',
#  '190540107070',
#  '190540107149',
#  '190540107118',
#  '190540107187',
#  '190540107057',
#  '190540107036',
#  '190540107174',
#  '190540107097',
#  '190540107136',
#  '190540107124',
#  '190540107197',
#  '190540107137',
#  '190540107138',
#  '190540107079',
#  '190540107120',
#  '190540107167',
#  '200540107510',
#  '190540107146',
#  '190540107153',
#  '190540107073',
#  '190540107139',
#  '190540107108',
#  '190540107180',
#  '190540107135',
#  '190540107048',
#  '190540107131',
#  '190540107011',
#  '190540107029',
#  '190540107010',
#  '190540107189',
#  '190540107067',
#  '200540107507',
#  '190544107001',
#  '190540107143',
#  '200540107512',
#  '190540107198',
#  '190540107169',
#  '190540107069',
#  '190540107114',
#  '190540107199',
#  '190540107213',
#  '190540107051',
#  '200540107518',
#  '190540107002',
#  '200540107522',
#  '190540107037',
#  '190540107083',
#  '190540107129',
#  '190540107144',
#  '190540107206',
#  '200540107503',
#  '200540107506',
#  '200540107513',
#  '190540107021',
#  '190540107046',
#  '190540107089',
#  '190540107107',
#  '200540107521',
#  '190540107134',
#  '190540107041',
#  '190540107141',
#  '190540107031',
#  '190540107049',
#  '190540107012',
#  '190540107091',
#  '190540107147',
#  '190540107096',
#  '190540107220',
#  '200540107505',
#  '190540107087',
#  '190540107103',
#  '190540107050',
#  '190540107063',
#  '190540107072',
#  '190540107098',
#  '190540107100',
#  '190540107111',
#  '190540107155',
#  '190540107168',
#  '190540107170',
#  '19054010721',
#  '190540107183',
#  '190540107179',
#  '190540107202',
#  '200540107508',
#  '190540107023',
#  '190540107159',
#  '190540107094',
#  '190540107215',
#  '190540107078',
#  '190540107017',
#  '200540107501',
#  '190540107205',
#  '190540107045',
#  '190540107053',
#  '190540107054',
#  '190540107040',
#  '190540107221',
#  '190540107163',
#  '200540107524']

# %%
placement = []
for i in range(19,297):# starting from 19 
    if i%2==0: # studentdata is on even place 
        a = soup.select("span")[i].text.strip()
        placement.append(a)
placement
# Out:
# ['20.00 Lac',
#  '10.00 Lac',
#  '8.00-9.00 Lac',
#  '8.00-9.00 Lac',
#  '8.00-9.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00-7.00 Lac',
#  '6.00 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.80 Lac',
#  '4.32 - 4.80 Lac',
#  '4.32 - 4.80 Lac',
#  '4.32 - 4.80 Lac',
#  '4.32 - 4.80 Lac',
#  '4.32 - 4.80 Lac',
#  '4.50 Lac',
#  '4.50 Lac',
#  '4.50 Lac',
#  '4.50 Lac',
#  '4.50 Lac',
#  '4.50 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.20 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '3.50-4.50 Lac',
#  '3.50-4.50 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '3.00-5.00 Lac',
#  '4.00 Lac',
#  '4.00 Lac',
#  '3.00-4.80 Lac',
#  '3.84 Lac',
#  '3.60-4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.50 - 4.00 Lac',
#  '3.72 Lac',
#  '3.60 Lac',
#  '3.60 Lac',
#  '3.60 Lac',
#  '3.60 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.50 Lac',
#  '3.00-3.50 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  '3.00 Lac',
#  'Confidential',
#  'Confidential',
#  'Confidential',
#  'Confidential',
#  '2.64 Lac',
#  '2.64 Lac',
#  '']

# %%
df = pd.DataFrame({
    'Student Name' : Studentname,
    'Enrollment number' : enrollment,
    'Placement' : placement
})

# %%
df
# Out:
#          Student Name Enrollment number      Placement
# 0    KATHANLUNAGARIYA      190540107121      20.00 Lac
# 1          DHAVALBERA      190540107007      10.00 Lac
# 2          SOHAMJOSHI      190540107085  8.00-9.00 Lac
# 3       IKSHIKACHOTAI      190540107030  8.00-9.00 Lac
# 4     DRASHTIATKOTIYA      190540107005  8.00-9.00 Lac
# ..                ...               ...            ...
# 134       PRINCEFALDU      190540107054   Confidential
# 135    RUSHIKDARANIYA      190540107040   Confidential
# 136       ISHITVASOYA      190540107221       2.64 Lac
# 137       KRUNALPATEL      190540107163       2.64 Lac
# 138        YASHRATHOD      200540107524
#
# [139 rows x 3 columns]

# %% [markdown]
# # Write a python program to perform database operations on database using mysql and sqlite3.
# 1)	 Display Student table from database.<br>
# 2)	Insert new recode into student table by user.
